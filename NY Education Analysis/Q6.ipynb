# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

df = pd.read_csv("middleSchoolData.csv")  
df = df.drop(columns=['dbn', 'school_name'])

df=(df-df.mean())/df.std()

df= df.dropna(subset = ["per_pupil_spending","avg_class_size","student_achievement","student_achievement","reading_scores_exceed","math_scores_exceed"])




PPS = df["per_pupil_spending"]
ACS = df["avg_class_size"]
SA = df["acceptances"]

y = df1["student_achievement"] + df1["reading_scores_exceed"] + df1["math_scores_exceed"]
MOA=y/3





PPSvsSA = PPS.corr(SA)
PPSvsMOA = PPS.corr(MOA)
ACSvsSA = ACS.corr(SA)
ACSvsMOA = ACS.corr(MOA)
print(PPSvsSA) 
print(PPSvsMOA) 
print(ACSvsSA) 
print(ACSvsMOA) 
#plt.scatter(PPS,SA)
#plt.scatter(PPS,MOA)
#plt.scatter(ACS,SA)
plt.scatter(ACS,MOA)
# Out:
# -0.33697267345267445
# -0.44290689081093726
# 0.3486863202664114
# 0.5048063052192899
