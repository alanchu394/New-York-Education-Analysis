# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("middleSchoolData.csv")  


acceptanceRates  = df["acceptances"] / df["applications"]
maxVal = np.argmax(acceptanceRates)
print(acceptanceRates[maxVal])
print(df["acceptances"][maxVal])
print(df["school_name"][maxVal])




plt.scatter(df["applications"],acceptanceRates)
# Out:
# 0.8167330677290837
# 205
# THE CHRISTA MCAULIFFE SCHOOL\I.S. 187
